# %% [markdown]
# <a href="https://colab.research.google.com/github/bbalbo/prediccion-de-ventas/blob/main/practica_visualization.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn

# %%
df_sports=pd.read_excel('/content/drive/MyDrive/data_sports.xlsx')
df_sports
# Out:
#                  Sport  2017  2013  2008  2007  2006  2005  2004
# 0             Football    37    39    41    43    43    34    37
# 1           Basketball    11    12     9    11    12    12    13
# 2             Baseball     9    14    10    13    11    12    10
# 3               Soccer     7     4     3     2     2     3     2
# 4           Ice hockey     4     3     4     4     2     4     3
# 5          Auto racing     2     2     3     3     4     5     5
# 6               Tennis     2     3     1     1     1     3     2
# 7                 Golf     1     2     2     2     3     2     2
# 8           Volleyball     1     0     1     0     0     1     0
# 9               Boxing     1     1     2     1     2     1     1
# 10          Gymnastics     1     0     1     1     1     0     1
# 11           Motocross     1     0     0     0     0     0     1
# 12  Ice/Figure skating     1     1     1     2     3     3     4
# ...

# %%
fig = plt.figure(dpi=100)
plt.plot(df_sports.iloc[0,1:], 'r*--', label=df_sports.iloc[0,0])
plt.plot(df_sports.iloc[1,1:], 'bs-', label=df_sports.iloc[1,0])
plt.plot(df_sports.iloc[2,1:], 'g-D', label=df_sports.iloc[2,0])
plt.title("What is America's most popular sport?")
plt.xlabel("Years")
plt.ylabel("Percentage of spectators")
plt.legend(loc='upper right')
plt.axis([2003,2018,0,55])

plt.show()

# %%
fig2 = plt.figure(dpi=100)
tiempo=[2017,2013,2008,2007,2006,2005,2004]
plt.bar(height=df_sports.iloc[6,1:], x=[2017,2013,2008,2007,2006,2005,2004], label=df_sports.iloc[0,0])
plt.title('Evolution of tennis')
plt.show()
